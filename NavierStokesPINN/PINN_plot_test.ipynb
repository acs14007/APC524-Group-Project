# %%
from abc import ABC, abstractmethod
import sys
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from scipy.interpolate import griddata
import time

from PINN import PhysicsInformedNN
from input_ouput import NavierStokesPINN_IO
from plotting import NavierStokesPINN_Plotter
# Out:
# 2023-12-18 22:01:19.512971: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.14.0

# %%
IO_manager = NavierStokesPINN_IO('data', 'ouput')
IO_manager.parse_data_file('cylinder_nektar_wake.mat')
# Select time index to test on

# %%
time_snap_idx = 40
IO_manager.select_test_data(time_snap_idx)

# %%
Plot_manager = NavierStokesPINN_Plotter('data', 'plots', IO_manager)
Plot_manager.plot_compare_predictions('predictions_dictionary.npz', time_snap_idx)
